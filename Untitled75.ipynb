# %% [markdown]
# <a href="https://colab.research.google.com/github/fedor44/paper13_lstm_2/blob/main/Untitled75.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Activation
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from google.colab import drive
drive.mount('/content/drive/')
import pandas as pd

from keras import regularizers
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt


# 주식 정보 및 감성 분석 데이터 파일
df_aapl = pd.read_csv('/content/drive/MyDrive/paper/stock/df_aapl.csv')
df_msft = pd.read_csv('/content/drive/MyDrive/paper/stock/df_msft.csv')
df_avgo = pd.read_csv('/content/drive/MyDrive/paper/stock/df_avgo.csv')

# 필요한 데이터만 남기고 정리
df_aapl_1 = df_aapl[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'vaderScore']]
df_aapl_2 = df_aapl[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'finbertScore']]
df_aapl_3 = df_aapl[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'finetunedFinbertScore']]

df_msft_1 = df_msft[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'vaderScore']]
df_msft_2 = df_msft[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'finbertScore']]
df_msft_3 = df_msft[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'finetunedFinbertScore']]

df_avgo_1 = df_avgo[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'vaderScore']]
df_avgo_2 = df_avgo[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'finbertScore']]
df_avgo_3 = df_avgo[['date', 'Open', 'High', 'Low', 'Close', 'Volume', 'finetunedFinbertScore']]

# 결측치 드롭
df_aapl_1 = df_aapl_1.dropna()
df_aapl_2 = df_aapl_2.dropna()
df_aapl_3 = df_aapl_3.dropna()

df_msft_1 = df_msft_1.dropna()
df_msft_2 = df_msft_2.dropna()
df_msft_3 = df_msft_3.dropna()

df_avgo_1 = df_avgo_1.dropna()
df_avgo_2 = df_avgo_2.dropna()
df_avgo_3 = df_avgo_3.dropna()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df_aapl_1
# Out:
#             date        Open        High         Low       Close     Volume  \
# 0     2018-01-02   40.175166   40.680425   39.962672   40.670979  102223600
# 1     2018-01-02   40.175166   40.680425   39.962672   40.670979  102223600
# 3     2018-01-04   40.737073   40.956650   40.628468   40.852764   89738400
# 4     2018-01-04   40.737073   40.956650   40.628468   40.852764   89738400
# 5     2018-01-04   40.737073   40.956650   40.628468   40.852764   89738400
# ...          ...         ...         ...         ...         ...        ...
# 2315  2023-05-18  172.319496  174.550690  171.901150  174.361435   65496700
# 2316  2023-05-19  175.696181  175.696181  174.251888  174.471024   55772400
# 2317  2023-05-22  173.295635  174.022774  172.767721  173.514771   43570900
# 2318  2023-05-22  173.295635  174.022774  172.767721  173.514771   43570900
# 2319  2023-05-23  172.448994  172.698011  170.606265  170.885162   50747300
#
#       vaderScore
# 0         0.2982
# 1         0.3415
# 3        -0.1583
# 4         0.3975
# 5         0.5548
# ...          ...
# 2315     -0.1192
# 2316     -0.2453
# 2317      0.5029
# 2318     -0.5997
# 2319      0.2751
#
# [2038 rows x 7 columns]

# %%
# https://github.com/ZainUlMustafa/Stock-Prediction-using-News-Info-Sentiment/blob/master/sentiment_analysis.ipynb
# Creating a function to preprocess the dataset

def createDataset(dataset, target, lookBack=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - lookBack):
        a = dataset[i:(i + lookBack), :]
        dataX.append(a)
        dataY.append(target[i + lookBack])
    return np.array(dataX), np.array(dataY)
#enddef

# %%
# 로드한 데이터셋
df = df_avgo_3

# Preproccessing the dataset for LSTM
features = df.drop(['date', 'Close'], axis=1).values
target = df['Close'].values

scalerFeatures = MinMaxScaler(feature_range=(0, 1))
scalerTarget = MinMaxScaler(feature_range=(0, 1))

featuresScaled = scalerFeatures.fit_transform(features)
targetScaled = scalerTarget.fit_transform(target.reshape(-1, 1))

lookBack = 3
X, y = createDataset(featuresScaled, targetScaled, lookBack)
print(X[:2])
print(y[:2])

trainSize = int(len(X) * 0.8)
testSize = len(X) - trainSize
trainX, testX = X[0:trainSize, :], X[trainSize:len(X), :]
trainY, testY = y[0:trainSize], y[trainSize:len(y)]

trainX = np.reshape(trainX, (trainX.shape[0], lookBack, trainX.shape[2]))
testX = np.reshape(testX, (testX.shape[0], lookBack, testX.shape[2]))
# Out:
# [[[0.07436158 0.06517129 0.09473555 0.03975411 0.50013267]
#   [0.0757173  0.06471902 0.09311207 0.03359738 0.54945193]
#   [0.0757173  0.06471902 0.09311207 0.03359738 0.11395963]]
#
#  [[0.0757173  0.06471902 0.09311207 0.03359738 0.54945193]
#   [0.0757173  0.06471902 0.09311207 0.03359738 0.11395963]
#   [0.06628977 0.05664378 0.08315199 0.06038363 0.99345047]]]
# [[0.08000565]
#  [0.08000565]]

# %%
# Building the LSTM model

batchSize = 32
epoch = 30
neurons = 100
dropout = 0.2

model = Sequential()
model.add(LSTM(neurons, return_sequences=True, activation='tanh', input_shape=(lookBack, features.shape[1]), name='lstm_1'))
model.add(Dropout(dropout, name='dropout_1'))
model.add(LSTM(neurons, return_sequences=True, activation='tanh', name='lstm_2'))
model.add(Dropout(dropout, name='dropout_2'))
model.add(LSTM(neurons, activation='tanh', name='lstm_3'))
model.add(Dropout(dropout, name='dropout_3'))

model.add(Dense(units=1, activation='linear', activity_regularizer=regularizers.l1(0.00001)))
model.add(Activation('tanh', name='activation_1'))
model.summary()

model.compile(loss='mean_squared_error' , optimizer='adam') # (adam 학습률 = 0.001)

#restore_best_weights: True로 설정하면, 조기 종료 시점에서 가장 좋은 모델의 가중치를 복원합니다. 즉, 학습 과정에서 가장 낮은 검증 손실을 가진 모델의 가중치를 사용합니다.
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.fit(trainX, trainY, batch_size=batchSize, epochs=epoch, verbose=1, validation_split=0.2, callbacks=[early_stopping])
#model.fit(trainX, trainY, epochs=epoch, batch_size=batchSize, verbose=1, validation_split=0.2)
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 3, 100)            42400
#
#  dropout_1 (Dropout)         (None, 3, 100)            0
#
#  lstm_2 (LSTM)               (None, 3, 100)            80400
#
#  dropout_2 (Dropout)         (None, 3, 100)            0
#
#  lstm_3 (LSTM)               (None, 100)               80400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_26 (Dense)            (None, 1)                 101
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 203301 (794.14 KB)
# Trainable params: 203301 (794.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 8s 340ms/step - loss: 0.0171 - val_loss: 0.1879
# Epoch 2/30
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0084 - val_loss: 0.1022
# Epoch 3/30
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0086 - val_loss: 0.1239
# Epoch 4/30
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0073 - val_loss: 0.1372
# Epoch 5/30
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0058 - val_loss: 0.0889
# Epoch 6/30
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0051 - val_loss: 0.0442
# Epoch 7/30
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0034 - val_loss: 0.0317
# Epoch 8/30
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0018 - val_loss: 0.0057
# Epoch 9/30
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 10/30
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0016 - val_loss: 0.0033
# Epoch 11/30
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 12/30
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0036
# Epoch 13/30
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 14/30
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 15/30
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 16/30
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 17/30
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 18/30
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 19/30
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 20/30
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 21/30
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 22/30
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 23/30
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 24/30
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 25/30
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0011 - val_loss: 0.0018

# %%
#!pip install graphviz
#!pip install pydot
#from tensorflow.keras.utils import plot_model

#plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# Running prediction over the training set and testing set

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

trainPredictInv = scalerTarget.inverse_transform(trainPredict)
trainYInv = scalerTarget.inverse_transform(np.reshape(trainY, (trainY.shape[0], 1)))
testPredictInv = scalerTarget.inverse_transform(testPredict)
testYInv = scalerTarget.inverse_transform(np.reshape(testY, (testY.shape[0], 1)))
# Out:
# 6/6 [==============================] - 2s 7ms/step
# 2/2 [==============================] - 0s 9ms/step

# %%
# Calculating the score and accuracy of the model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# MAE 계산
trainMAE = mean_absolute_error(trainYInv[:, 0], trainPredictInv[:, 0])
testMAE = mean_absolute_error(testYInv[:, 0], testPredictInv[:, 0])
print(f'Training MAE: {trainMAE}')
print(f'Testing MAE: {testMAE}')

# RMSE 계산
trainRMSE = np.sqrt(mean_squared_error(trainYInv[:, 0], trainPredictInv[:, 0]))
testRMSE = np.sqrt(mean_squared_error(testYInv[:, 0], testPredictInv[:, 0]))
print(f'Training RMSE: {trainRMSE}')
print(f'Testing RMSE: {testRMSE}')

# R² Score 계산
trainR2 = r2_score(trainYInv[:, 0], trainPredictInv[:, 0])
testR2 = r2_score(testYInv[:, 0], testPredictInv[:, 0])
print(f'Training R² Score: {trainR2}')
print(f'Testing R² Score: {testR2}')

# 정확도 계산
trainAccuracy = 100 - (trainRMSE / np.mean(trainYInv) * 100)
testAccuracy = 100 - (testRMSE / np.mean(testYInv) * 100)
print(f'Training Accuracy: {trainAccuracy:.2f}%')
print(f'Testing Accuracy: {testAccuracy:.2f}%')
# Out:
# Training MAE: 14.481709485613434
# Testing MAE: 27.384549967447928
# Training RMSE: 20.652119715031475
# Testing RMSE: 41.03150928318065
# Training R² Score: 0.9709010319389457
# Testing R² Score: 0.6373722987233328
# Training Accuracy: 92.93%
# Testing Accuracy: 92.52%

# %%
# Visualizing the data
# On the x-axis, the dates are displayed after every 30 days

dates = df['date'].values
sampleInterval = 60
sampledDates = dates[::sampleInterval]

plt.figure(figsize=(20, 10))
plt.plot(dates[:len(trainY)], trainY, label='Actual Train')
plt.plot(dates[:len(trainPredict)], trainPredict, label='Predicted Train')
plt.plot(dates[len(trainY):len(trainY) + len(testY)], testY, label='Actual Test')
plt.plot(dates[len(trainPredict):len(trainPredict) + len(testPredict)], testPredict, label='Predicted Test')

plt.xticks(sampledDates, rotation=90)

plt.legend()
plt.show()
